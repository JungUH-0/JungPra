# %% [markdown]
# <a href="https://colab.research.google.com/github/JungUH-0/JungPra/blob/main/pythonpra/colab/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%98%88%EC%A0%9C_20260325_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 문제] 컴퓨터와 가위바위보 게임을 코딩해 보세요. 5전 3승제로 먼저 이기는 사람을 알려주고, 축하의 인사도 출력해 보세요

# %%
# 사용자_가바보 = input("가위, 바위, 보 중에 하나를 선택/입력해 주세요: ")
# if 사용자_가바보 in ['가위', '바위', '보']:
#     print("사용자가 선택한 것은 {} 입니다".format(사용자_가바보))
# else:
#     print("사용자가 잘못 선택했어요")

사용자_가바보 = None
while True:
    사용자_가바보 = input("가위, 바위, 보 중에 하나를 선택/입력해 주세요: ")
    if 사용자_가바보 in ['가위', '바위', '보']:
        break
    print("사용자가 잘못 선택했어요")
# Out:
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위

# %%
import random

리스트_가바보 = ['가위', '바위', '보']
#컴퓨터_가바보 = random.randint(0,2)
#컴퓨터_가바보 = 리스트_가바보[컴퓨터_가바보]
컴퓨터_가바보 = 리스트_가바보[random.randint(0,2)]

print("컴퓨터가 선택한 것은 {} 입니다".format(컴퓨터_가바보))
# Out:
# 컴퓨터가 선택한 것은 가위 입니다

# %%
리스트_가바보 = {0:'가위', 1:'바위', 2:'보'}
컴퓨터_가바보 = random.randint(0,2)
컴퓨터_가바보 = 리스트_가바보[컴퓨터_가바보]

print("컴퓨터가 선택한 것은 {} 입니다".format(컴퓨터_가바보))
# Out:
# 컴퓨터가 선택한 것은 가위 입니다

# %%
if 사용자_가바보 == '바위' and 컴퓨터_가바보 == '가위':
    pass
elif 사용자_가바보 == '바위' and 컴퓨터_가바보 == '보':
    pass
else:
    pass

# %%
if 사용자_가바보 == '바위':
    if 컴퓨터_가바보 == '가위':
        pass
    elif 컴퓨터_가바보 == '보':
        pass
    else:
        pass
elif 사용자_가바보 == '가위':
    pass
else:
    pass

# %%
import random
user_rsp=None #유저 선언 이거 없이

list_rsp=['가위','바위','보']#가위바위보 리스트

com_rsp=list_rsp[random.randint(0,2)] #컴퓨터의 랜덤숫자의 인자로 리스트에서 value 뽑기
dic_rsp={0:'가위',1:'바위',2:'보'} #가위바위보 dic
ran=random.randint(0,2) #랜덤숫자 뽑아놓기
com_rsp = dic_rsp[ran]# 랜덤숫자로 dic의 key값을 대입해서 value 뽑기
print(com_rsp)
dic_referee ={'가위':{'가위':'비김','바위':'패배','보':'승리'}, #dic 안에 dic
              '바위':{'가위':'승리','바위':'비김','보':'패배'},
              '보':{'가위':'패배','바위':'승리','보':'비김'}}
while True:
    user_rsp = input("가위, 바위, 보 중에 하나를 선택/입력해 주세요: ") #바로 이렇게 선언후에 사용가능
    if user_rsp in list_rsp :
        break
    print("사용자가 잘못 선택했어요")
print(dic_referee[user_rsp][com_rsp])

# %%
user_rsp=None #유저 선언
list_rsp=['가위','바위','보']#가위바위보 리스트
com_rsp=list_rsp[random.randint(0,2)] #컴퓨터의 랜덤숫자의 인자로 리스트에서 value 뽑기
print(random.randint(0,2))#랜덤확인

# %%
import random

ran_rsp = ["Rock", "Scissors", "Paper" ]

count=5
u_score=0
c_score=0

while True :
    computer = random.randint(0,2)

    while True :
        user = int(input("0.Rock, 1.Scissors, 2.Paper input your number on 0,1,2 : "))

        if (user == computer) :
            count -= 1
            print("컴퓨터는 ",ran_rsp[computer],", 유저는 " ,ran_rsp[user],"입니다.")
            print("무승부 입니다.\n횟수는 ", count, "회 남았습니다.")
            break

        elif (user == 0 and computer ==1) or (user == 1 and computer ==2) or (user == 2 and computer ==0):
            count -= 1
            u_score += 1
            print("컴퓨터는 ",ran_rsp[computer],", 유저는 " ,ran_rsp[user],"입니다.")
            print("유저의 승리입니다. 승점 1점을 획득하셨습니다. \n총 승점 ", u_score,"점 입니다."\
                  "\n횟수는 ", count, "회 남았습니다.")
            break

        else :
            count -= 1
            c_score += 1
            print("컴퓨터는 ", ran_rsp[computer] ,", 유저는 ", ran_rsp[user],"입니다.")
            print("컴퓨터의 승리입니다. \n총 승점 ", u_score,"점 입니다." \
                "\n횟수는 ", count, "회 남았습니다.")
            break

    if u_score >= 3 :
        print("축하합니다. 유저의 승리입니다!")
        break

    elif c_score >= 3 :
        print("컴퓨터가 승리했습니다.")
        break

    elif count == 0 :
        print("횟수가 전부 소모 되었습니다.")
        count=5
        u_score=0
        c_score=0
        print(count)
        print(u_score)
        print(c_score)

# %%
리스트_가바보_심판 = [
    [None, '컴', '사'], #사용자가 가위: 0, 리스트_가바보_심판[0]
    ['사', None, '컴'], #사용자가 바위: 1, 리스트_가바보_심판[1]
    ['컴', '사', None]  #사용자가   보: 2, 리스트_가바보_심판[2]
]
print(리스트_가바보_심판[0][2])
# Out:
# 사

# %%
사전_가바보_심판 = {
    '가위':{'가위': None, '바위': '컴', '보': '사'},
    '바위':{'가위': '사', '바위': None, '보': '컴'},
    '보':{'가위': '컴', '바위': '사', '보': None}
}
print(사전_가바보_심판['가위']['가위'])
# Out:
# None

# %%
사용자_승리횟수 = 0
컴퓨터_승리횟수 = 0
#사용자_승리횟수 = 컴퓨터_승리횟수 = 0
#사용자_승리횟수, 컴퓨터_승리횟수 = 0, 0
승자 = 사전_가바보_심판[사용자_가바보][컴퓨터_가바보]
if 승자 == '사':
    사용자_승리횟수 = 사용자_승리횟수 + 1
elif 승자 == '컴':
    컴퓨터_승리횟수 = 컴퓨터_승리횟수 + 1
print(승자)
# Out:
# None

# %%
사용자_승리횟수 = 0
컴퓨터_승리횟수 = 0

count = 0
while count < 10:
    count = count + 1
    #사용자의 가위바위보 선택
    사용자_가바보 = None
    # while True:
    #     사용자_가바보 = input("가위, 바위, 보 중에 하나를 선택/입력해 주세요: ")
    #     if 사용자_가바보 in ['가위', '바위', '보']:
    #         break
    #     print("사용자가 잘못 선택했어요")

    #컴퓨터의 가위바위보 선택
    리스트_가바보 = {0:'가위', 1:'바위', 2:'보'}
    컴퓨터_가바보 = random.randint(0,2)
    컴퓨터_가바보 = 리스트_가바보[컴퓨터_가바보]
    #print("컴퓨터가 선택한 것은 {} 입니다".format(컴퓨터_가바보))
    print("리스크_가바보의 주소: ", id(리스트_가바보))

    #승부결정
    # 사전_가바보_심판 = {
    #     '가위':{'가위': None, '바위': '컴', '보': '사'},
    #     '바위':{'가위': '사', '바위': None, '보': '컴'},
    #     '보':{'가위': '컴', '바위': '사', '보': None}
    # }
    # 승자 = 사전_가바보_심판[사용자_가바보][컴퓨터_가바보]

    # #승 횟수 누적
    # if 승자 == '사':
    #     사용자_승리횟수 = 사용자_승리횟수 + 1
    #     print("{}가 승리했어요.({} 승리횟수: {})".format('사용자', '사용자', 사용자_승리횟수))
    # elif 승자 == '컴':
    #     컴퓨터_승리횟수 = 컴퓨터_승리횟수 + 1
    #     print("{}가 승리했어요.({} 승리횟수: {})".format('컴퓨터', '컴퓨터', 컴퓨터_승리횟수))
    # else:
    #     print("이번판은 무승부예요")

    # if 사용자_승리횟수 >= 3 or 컴퓨터_승리횟수 >= 3:
    #     break
# Out:
# 리스크_가바보의 주소:  137596626230272
# 리스크_가바보의 주소:  137596626284096
# 리스크_가바보의 주소:  137596626230272
# 리스크_가바보의 주소:  137596626284096
# 리스크_가바보의 주소:  137596626230272
# 리스크_가바보의 주소:  137596626284096
# 리스크_가바보의 주소:  137596626230272
# 리스크_가바보의 주소:  137596626284096
# 리스크_가바보의 주소:  137596626230272
# 리스크_가바보의 주소:  137596626284096

# %%
사용자_승리횟수 = 0
컴퓨터_승리횟수 = 0

리스트_가바보 = {0:'가위', 1:'바위', 2:'보'}
사전_가바보_심판 = {
        '가위':{'가위': None, '바위': '컴', '보': '사'},
        '바위':{'가위': '사', '바위': None, '보': '컴'},
        '보':{'가위': '컴', '바위': '사', '보': None}
    }

while True:
    #사용자의 가위바위보 선택
    사용자_가바보 = None
    while True:
        사용자_가바보 = input("가위, 바위, 보 중에 하나를 선택/입력해 주세요: ")
        if 사용자_가바보 in ['가위', '바위', '보']:
            break
        print("사용자가 잘못 선택했어요")

    #컴퓨터의 가위바위보 선택
    컴퓨터_가바보 = 리스트_가바보[random.randint(0,2)]
    #print("컴퓨터가 선택한 것은 {} 입니다".format(컴퓨터_가바보))

    #승부결정
    승자 = 사전_가바보_심판[사용자_가바보][컴퓨터_가바보]

    # #승 횟수 누적
    if 승자 == '사':
        사용자_승리횟수 = 사용자_승리횟수 + 1
        print("{}가 승리했어요.({} 승리횟수: {})".format('사용자', '사용자', 사용자_승리횟수))
    elif 승자 == '컴':
        컴퓨터_승리횟수 = 컴퓨터_승리횟수 + 1
        print("{}가 승리했어요.({} 승리횟수: {})".format('컴퓨터', '컴퓨터', 컴퓨터_승리횟수))
    else:
        print("이번판은 무승부예요")

    if 사용자_승리횟수 >= 3 or 컴퓨터_승리횟수 >= 3:
        break
# Out:
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 컴퓨터가 승리했어요.(컴퓨터 승리횟수: 1)
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 사용자가 승리했어요.(사용자 승리횟수: 1)
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 사용자가 승리했어요.(사용자 승리횟수: 2)
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 사용자가 승리했어요.(사용자 승리횟수: 3)

# %%
def 가바보_선택(누구):
    가바보 = None
    if 누구 == '사용자':
        while True:
            가바보 = input("가위, 바위, 보 중에 하나를 선택/입력해 주세요: ")
            if 가바보 in ['가위', '바위', '보']:
                break
            print("사용자가 잘못 선택했어요")
    else:
        가바보 = 리스트_가바보[random.randint(0,2)]

    return 가바보

가바보_선택('컴퓨터')
# Out:
# '바위'

# %%
def 승부결정_승횟수누적(사용자_가바보, 컴퓨터_가바보, 승리횟수누적):
    승자 = 사전_가바보_심판[사용자_가바보][컴퓨터_가바보]

    if 승자 == '사':
        승리횟수누적[승자] = 승리횟수누적[승자] + 1
        print("{}가 승리했어요.({} 승리횟수: {})".format('사용자', '사용자', 사용자_승리횟수))
    elif 승자 == '컴':
        승리횟수누적[승자] = 승리횟수누적[승자] + 1
        print("{}가 승리했어요.({} 승리횟수: {})".format('컴퓨터', '컴퓨터', 컴퓨터_승리횟수))
    else:
        print("이번판은 무승부예요")

    return 승리횟수누적

# %%
승리횟수 = {'사': 0, '컴': 0}

리스트_가바보 = {0:'가위', 1:'바위', 2:'보'}
사전_가바보_심판 = {
        '가위':{'가위': None, '바위': '컴', '보': '사'},
        '바위':{'가위': '사', '바위': None, '보': '컴'},
        '보':{'가위': '컴', '바위': '사', '보': None}
    }

while True:
    #사용자의 가위바위보 선택
    사용자_가바보 = 가바보_선택('사용자')
    컴퓨터_가바보 = 가바보_선택('컴퓨터')

    #승부결정, 승 횟수 누적
    승부횟수 = 승부결정_승횟수누적(사용자_가바보, 컴퓨터_가바보, 승리횟수)

    if 승리횟수['사'] >= 3 or 승리횟수['컴'] >= 3:
        break
# Out:
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 이번판은 무승부예요
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 컴퓨터가 승리했어요.(컴퓨터 승리횟수: 1)
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 사용자가 승리했어요.(사용자 승리횟수: 3)
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 컴퓨터가 승리했어요.(컴퓨터 승리횟수: 1)
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 이번판은 무승부예요
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 컴퓨터가 승리했어요.(컴퓨터 승리횟수: 1)

# %%
import random

def 가바보_선택(누구):
    가바보 = None
    if 누구 == '사용자':
        while True:
            가바보 = input("가위, 바위, 보 중에 하나를 선택/입력해 주세요: ")
            if 가바보 in ['가위', '바위', '보']:
                break
            print("사용자가 잘못 선택했어요")
    else:
        가바보 = 리스트_가바보[random.randint(0,2)]

    return 가바보

def 승부결정_승횟수누적(사용자_가바보, 컴퓨터_가바보, 승리횟수누적):
    승자 = 사전_가바보_심판[사용자_가바보][컴퓨터_가바보]

    if 승자 == '사':
        승리횟수누적[승자] = 승리횟수누적[승자] + 1
        print("{}가 승리했어요.({} 승리횟수: {})".format('사용자', '사용자', 승리횟수누적['사']))
    elif 승자 == '컴':
        승리횟수누적[승자] = 승리횟수누적[승자] + 1
        print("{}가 승리했어요.({} 승리횟수: {})".format('컴퓨터', '컴퓨터', 승리횟수누적['컴']))
    else:
        print("이번판은 무승부예요")

    return 승리횟수누적

승리횟수 = {'사': 0, '컴': 0}

리스트_가바보 = {0:'가위', 1:'바위', 2:'보'}
사전_가바보_심판 = {
        '가위':{'가위': None, '바위': '컴', '보': '사'},
        '바위':{'가위': '사', '바위': None, '보': '컴'},
        '보':{'가위': '컴', '바위': '사', '보': None}
    }

while True:
    #사용자의 가위바위보 선택
    사용자_가바보 = 가바보_선택('사용자')
    컴퓨터_가바보 = 가바보_선택('컴퓨터')

    #승부결정, 승 횟수 누적
    승부횟수 = 승부결정_승횟수누적(사용자_가바보, 컴퓨터_가바보, 승리횟수)

    if 승리횟수['사'] >= 3 or 승리횟수['컴'] >= 3:
        break
# Out:
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 사용자가 승리했어요.(사용자 승리횟수: 1)
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 이번판은 무승부예요
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 이번판은 무승부예요
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 사용자가 승리했어요.(사용자 승리횟수: 2)
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 이번판은 무승부예요
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 이번판은 무승부예요
# 가위, 바위, 보 중에 하나를 선택/입력해 주세요: 가위
# 사용자가 승리했어요.(사용자 승리횟수: 3)
