# %% [markdown]
# <a href="https://colab.research.google.com/github/JungUH-0/JungPra/blob/main/pythonpra/colab/%EC%9E%90%EB%A3%8C%EA%B5%AC%EC%A1%B0List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile /content/drive/MyDrive/mylist.py
class data_List :
    def __init__(self,size):
        self.data_list=[None]*size
        self.maxsize=size
        self.length=0

    def isFull (self):
        if self.maxsize == self.length :
            return True
        else:
            return False

    def  isEmpty (self):
        if self.length == 0 :
            return True
        else:
            return False
    def Print(self,str):
        pass


    def insert (self,pos,e):

        if self.isFull() == True :
            print("size over")
            return

        if self.data_list[pos] != None :
            temp_ori = self.data_list[pos] #원본데이터
            self.data_list[pos]=e
            for i in range(pos, self.length-1):
                temp = self.data_list[i+1]
                self.data_list[i+1] = temp_ori
                temp_ori = temp

            self.data_list[self.length] = temp_ori # 마지막값
            self.length +=1
        else :
            self.data_list[pos] = e
            self.length +=1

    def delete (self,pos):
        if self.isEmpty() == True :
            print("empty")
            return
        if self.data_list[pos] == None :
            print("already None")
            return
        else :
            # 맨 뒤의 값을 가져와서 기억하고 당기기
            # temp_ori = self.data_list[self.length-1]
            # print(temp_ori)
            # for i in range(self.length-2,pos-1,-1):
            #     # print (i)
            #     temp = self.data_list[i]
            #     # print (temp)
            #     self.data_list[i] = temp_ori
            #     temp_ori=temp
            # self.data_list[self.length-1] = None
            #----------------------------------------
            # pos 부터 시작해서 다음 값을 기억할 필요없이 바로 대입
            for i in range(pos,self.length-1) :
                self.data_list[i]=self.data_list[i+1]
            self.data_list[self.length-1] = None
            self.length -=1

    def getEntry(self,pos):
        if self.data_list[pos] == None :
            print("None!")
            return
        else :
            return self.data_list[pos]

    def size(self):
        return self.length

    def clear(self):
        for i in range(self.length):
            self.data_list[i] = None

    def find(self,item):
        result = None
        for i in range(self.length):
            if self.data_list[i] == item :
                result = i
        if result != None :
            # print(item,"의 위치는",result)
            return result
        else :
            print("no data")
            return

    def replace(self,pos,item) :
        self.data_list[pos] = item

    def append(self,e):
        self.data_list[self.length] = e
        self.length += 1

    def display(self):
        print(self.data_list)

    def bigSort(self):
        #큰수
       for i in range(self.size()-1) :
            for j in range(i+1,self.size()):
                if(type(self.data_list[i]) == type(self.data_list[j])
                and (self.data_list[i] is not None) and (self.data_list[j] is not None)):
                    if(self.data_list[i]<self.data_list[j]):
                        temp = self.data_list[i]
                        self.data_list[i]=self.data_list[j]
                        self.data_list[j]=temp
                        #self.data_list [i], self.data_list [j] = self.data_list [j], self.data_list [i]
                else:
                    continue
# Out:
# Writing /content/drive/MyDrive/mylist.py

# %%
class data_List :
    def __init__(self,size):
        self.data_list=[None]*size
        self.size=size
        self.length=0

    def make_IsFull (self):
        if self.size == self.length :
            return True
        else:
            return False

    def  make_IsEmpty (self):
        if self.length == 0 :
            return True
        else:
            return False
    def make_Print(self,str):
        pass


    def make_Insert (self,pos,e):

        if self.make_IsFull() == True :
            print("size over")
            return

        if self.data_list[pos] != None :
            temp_ori = self.data_list[pos] #원본데이터
            self.data_list[pos]=e
            for i in range(pos, self.length-1):
                temp = self.data_list[i+1]
                self.data_list[i+1] = temp_ori
                temp_ori = temp

            self.data_list[self.length] = temp_ori # 마지막값
            self.length +=1
        else :
            self.data_list[pos] = e
            self.length +=1

    def make_Delete (self,pos):
        if self.make_IsEmpty() == True :
            print("empty")
            return
        if self.data_list[pos] == None :
            print("already None")
            return
        else :
            # 맨 뒤의 값을 가져와서 기억하고 당기기
            # temp_ori = self.data_list[self.length-1]
            # print(temp_ori)
            # for i in range(self.length-2,pos-1,-1):
            #     # print (i)
            #     temp = self.data_list[i]
            #     # print (temp)
            #     self.data_list[i] = temp_ori
            #     temp_ori=temp
            # self.data_list[self.length-1] = None
            #----------------------------------------
            # pos 부터 시작해서 다음 값을 기억할 필요없이 바로 대입
            for i in range(pos,self.length-1) :
                self.data_list[i]=self.data_list[i+1]
            self.data_list[self.length-1] = None
            self.length -=1

    def make_getEntry(self,pos):
        if self.data_list[pos] == None :
            print("None!")
            return
        else :
            return self.data_list[pos]

    def make_Size(self):
        return self.length

    def make_Clear(self):
        for i in range(self.length):
            self.data_list[i] = None

    def make_Find(self,item):
        result = None
        for i in range(self.length):
            if self.data_list[i] == item :
                result = i
        if result != None :
            print(item,"의 위치는",result)
            return
        else :
            print("no data")
            return

    def make_Replace(self,pos,item) :
        self.data_list[pos] = item

    def make_Append(self,e):
        self.data_list[self.length] = e
        self.length += 1

    def make_Display(self):
        print(self.data_list)

    def make_BigSort(self):
        #큰수
       for i in range(self.make_Size()-1) :
            for j in range(i+1,self.make_Size()):
                if(type(self.data_list[i]) == type(self.data_list[j])
                and (self.data_list[i] is not None) and (self.data_list[j] is not None)):
                    if(self.data_list[i]<self.data_list[j]):
                        temp = self.data_list[i]
                        self.data_list[i]=self.data_list[j]
                        self.data_list[j]=temp
                        #self.data_list [i], self.data_list [j] = self.data_list [j], self.data_list [i]
                else:
                    continue

# %%
my_list = data_List(10)
my_list.make_Insert(4,10)
my_list.make_Display
print("length",my_list.length)

for i in range(10):
    my_list.make_Insert(i,i*10)

print("length",my_list.length)
print(my_list.data_list)
# print("empty",my_list.make_IsEmpty())
# print("full",my_list.make_IsFull())

my_list.make_Delete(0)
print(my_list.data_list)
my_list.make_Insert(0,8888)
my_list.make_Delete(3)
my_list.make_Delete(4)
# print("length",my_list.length)
print(my_list.data_list)
print("length",my_list.length)
my_list.make_Delete(8)
print(my_list.make_getEntry(0))

for i in range(my_list.length):
    print(my_list.make_getEntry(i))

my_list.make_Find(90)
my_list.make_Find(8888)
my_list.make_Find(1000)

# my_list.make_Clear()
print(my_list.data_list)
my_list.make_Append(9999)
print(my_list.data_list)
my_list.make_Replace(3,99)
my_list.make_Display()
my_list.make_BigSort()
my_list.make_Display()
# Out:
# length 1
# size over
# length 10
# [0, 10, 20, 30, 40, 50, 60, 70, 80, 10]
# [10, 20, 30, 40, 50, 60, 70, 80, 10, None]
# [8888, 10, 20, 40, 60, 70, 80, 10, None, None]
# length 8
# already None
# 8888
# 8888
# 10
# 20
# 40
# 60
# 70
# 80
# 10
# no data
# 8888 의 위치는 0
# no data
# [8888, 10, 20, 40, 60, 70, 80, 10, None, None]
# [8888, 10, 20, 40, 60, 70, 80, 10, 9999, None]
# [8888, 10, 20, 99, 60, 70, 80, 10, 9999, None]
# [9999, 8888, 99, 80, 70, 60, 20, 10, 10, None]

# %%
my_list = data_List(10)
my_list.make_Insert(4,10)
my_list.make_Display()
# Out:
# [None, None, None, None, 10, None, None, None, None, None]
